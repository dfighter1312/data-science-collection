# %% [markdown]
# # Making a content-based recommendation system
#
# This notebook attempts to make non-personalized recommendations based on the Netflix prize data.
#
# And since the original data only have the movie titles, we include an external data with more detailed movie information which can get from [a Kaggle discussion](https://www.kaggle.com/datasets/netflix-inc/netflix-prize-data/discussion/36670#527063). Thanks a lot for this piece of information.
#
# This is the second part of making recommendation systems. Full index of the series includes:
# 1. [Non-personalized recommendations](https://www.kaggle.com/code/dungdore1312/non-personalized-recommendations)
# 2. Content-based recommendations

# %% [markdown]
# # Reading DataFrames

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', 100)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import glob

rating_files = glob.glob('/kaggle/input/netflix-prize-data/combined_data_*.txt')
df_ratings = pd.concat([pd.read_csv(filename,
                                    header=None,
                                    names=['customer_id', 'rating', 'date'],
                                    parse_dates=['date']) for filename in rating_files])
df_ratings['movie_id'] = np.where(df_ratings['rating'].isna(), df_ratings['customer_id'], np.nan)
df_ratings['movie_id'] = df_ratings['movie_id'].str.split(':').str[0]
df_ratings['movie_id'] = df_ratings['movie_id'].fillna(method='ffill')
df_ratings.dropna(subset=['rating', 'date'], inplace=True)
df_ratings = df_ratings.astype({
    'customer_id': 'int',
    'movie_id': 'int'
})
df_ratings.drop_duplicates(inplace=True)

# %%
df_movies = pd.read_csv('/kaggle/input/modified-movie-titles/movies.csv',
                        parse_dates=['year_of_release'],
                        encoding='latin-1')

# %%
df_ratings.head()
# Out:
#    customer_id  rating       date  movie_id
# 1      1277134     1.0 2003-12-02      9211
# 2      2435457     2.0 2005-06-01      9211
# 3      2338545     3.0 2001-02-17      9211
# 4      2218269     1.0 2002-12-27      9211
# 5       441153     4.0 2002-10-11      9211

# %%
df_movies.head()
# Out:
#    movie_id year_of_release                         title
# 0         1      2003-01-01               Dinosaur Planet
# 1         2      2004-01-01    Isle of Man TT 2004 Review
# 2         3      1997-01-01                     Character
# 3         4      1994-01-01  Paula Abdul's Get Up & Dance
# 4         5      2004-01-01      The Rise and Fall of ECW

# %%
df_movies_info = pd.read_csv('/kaggle/input/movies-information/cooked_movies.csv')
df_movies_info.head()
# Out:
#    id    year                         title  Runtime  Rating  \
# 0   1  2003.0               Dinosaur Planet     50.0     7.7
# 1   2  2004.0    Isle of Man TT 2004 Review      NaN     NaN
# 2   3  1997.0                     Character    122.0     7.8
# 3   4  1994.0  Paula Abdul's Get Up & Dance     54.0     8.8
# 4   5  2004.0      The Rise and Fall of ECW    360.0     8.6
#
#              Directors                                          Writers  \
# 0  Pierre de Lespinois           Mike Carrol-Mike Carroll-Georgann Kane
# 1                  NaN                                              NaN
# 2        Mike van Diem  Ferdinand Bordewijk-Laurens Geels-Mike van Diem
# 3        Steve Purcell                                              NaN
# 4           Kevin Dunn                                      Paul Heyman
#
#                  Production companies                        Genres
# 0                                 NaN  Documentary-Animation-Family
# 1                                 NaN                           NaN
# 2  First Floor Features-Almerica Film           Crime-Drama-Mystery
# 3                                 NaN                        Family
# 4                      WWE Home Video             Documentary-Sport

# %%
df_movies_info.shape
# Out:
# (17769, 9)

# %%
# Drop movies with all null information
df_movies_info = df_movies_info.dropna(subset=["Runtime", "Rating", "Directors", "Writers", "Production companies", "Genres"])
df_movies_info.shape
# Out:
# (10248, 9)

# %%
df_movies = df_movies_info[["title", "Runtime", "Directors", "Writers", "Production companies", "Genres"]].merge(
    df_movies,
    on="title",
)
df_movies.head()
# Out:
#                         title  Runtime  \
# 0                   Character    122.0
# 1    The Rise and Fall of ECW    360.0
# 2                       8 Man     83.0
# 3  What the #$*! Do We Know!?    109.0
# 4    Class of Nuke 'Em High 2     90.0
#
#                                  Directors  \
# 0                            Mike van Diem
# 1                               Kevin Dunn
# 2                        Yasuhiro Horiuchi
# 3  William Arntz-Betsy Chasse-Mark Vicente
# 4                              Eric Louzil
#
#                                            Writers  \
# 0  Ferdinand Bordewijk-Laurens Geels-Mike van Diem
# 1                                      Paul Heyman
# 2                       Kazumasa Hirai-Jirô Kuwata
# 3       William Arntz-Betsy Chasse-Matthew Hoffman
# 4             Lloyd Kaufman-Carl Morano-Matt Unger
#
#                  Production companies  \
# 0  First Floor Features-Almerica Film
# 1                      WWE Home Video
# 2                      Rim Publishing
# 3     Captured Light-Lord of the Wind
# 4                 Troma Entertainment
#
#                                             Genres  movie_id year_of_release
# 0                              Crime-Drama-Mystery         3      1997-01-01
# 1                                Documentary-Sport         5      2004-01-01
# 2                                    Action-Sci-Fi         7      1992-01-01
# 3  Documentary-Comedy-Drama-Fantasy-Mystery-Sci-Fi         8      2004-01-01
# 4                             Comedy-Horror-Sci-Fi         9      1991-01-01

# %%
df_movies['movie_id'] = df_movies['movie_id'].astype(int)
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10884 entries, 0 to 10883
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 10884 non-null  object
#  1   Runtime               10884 non-null  float64
#  2   Directors             10884 non-null  object
#  3   Writers               10884 non-null  object
#  4   Production companies  10884 non-null  object
#  5   Genres                10884 non-null  object
#  6   movie_id              10884 non-null  int64
#  7   year_of_release       10884 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 765.3+ KB

# %% [markdown]
# # Feature Extraction
#
# ## Naive approach
# We will try to use one-hot encoding where the features are list of directors, writers, production companies, and genres.

# %%
# Modify some keywords containing '-' (e.g., Sci-fi) to avoid being splitted later
df_movies["Genres"] = df_movies["Genres"].str.replace("Sci-Fi", "SciFi")
df_movies["Genres"].head()
# Out:
# 0                               Crime-Drama-Mystery
# 1                                 Documentary-Sport
# 2                                      Action-SciFi
# 3    Documentary-Comedy-Drama-Fantasy-Mystery-SciFi
# 4                               Comedy-Horror-SciFi
# Name: Genres, dtype: object

# %%
cat_cols = ["Directors", "Writers", "Production companies", "Genres"]
df_movies_encoded = df_movies.copy(deep=True)

for col in cat_cols:
    df_movies_encoded[f"{col}_list"] = df_movies_encoded[col].str.split('-')
#     df_movies_encoded = df_movies_encoded.explode(f"{col}_list")
#     df_movies_encoded.reset_index(inplace=True, drop=True)
    
import itertools
df_movies_encoded["tags"] =  df_movies_encoded[[f"{col}_list" for col in cat_cols]].apply(lambda x: list(itertools.chain(*x)), axis=1)
df_movies_encoded = df_movies_encoded[["title", "Runtime", "tags"]]
df_movies_encoded.head()
# Out:
#                         title  Runtime  \
# 0                   Character    122.0
# 1    The Rise and Fall of ECW    360.0
# 2                       8 Man     83.0
# 3  What the #$*! Do We Know!?    109.0
# 4    Class of Nuke 'Em High 2     90.0
#
#                                                 tags
# 0  [Mike van Diem, Ferdinand Bordewijk, Laurens G...
# 1  [Kevin Dunn, Paul Heyman, WWE Home Video, Docu...
# 2  [Yasuhiro Horiuchi, Kazumasa Hirai, Jirô Kuwat...
# 3  [William Arntz, Betsy Chasse, Mark Vicente, Wi...
# 4  [Eric Louzil, Lloyd Kaufman, Carl Morano, Matt...

# %%
df_movies_encoded = df_movies_encoded.explode("tags")
df_movies_encoded
# Out:
#               title  Runtime                  tags
# 0         Character    122.0         Mike van Diem
# 0         Character    122.0   Ferdinand Bordewijk
# 0         Character    122.0         Laurens Geels
# 0         Character    122.0         Mike van Diem
# 0         Character    122.0  First Floor Features
# ...             ...      ...                   ...
# 10883  Alien Hunter     92.0       Sandstorm Films
# 10883  Alien Hunter     92.0                Action
# 10883  Alien Hunter     92.0             Adventure
# 10883  Alien Hunter     92.0                 SciFi
# 10883  Alien Hunter     92.0              Thriller
#
# [95604 rows x 3 columns]

# %%
# Unique tags
df_movies_encoded["tags"].nunique()
# Out:
# 24010

# %% [markdown]
# Due to the relatively high number of entities, we keep only 1k most common tags.

# %%
kept_tags = df_movies_encoded["tags"].value_counts().iloc[:1000].index
df_movies_encoded_filtered = df_movies_encoded[df_movies_encoded["tags"].isin(kept_tags)]
df_movies_encoded_filtered
# Out:
#                           title  Runtime              tags
# 0                     Character    122.0             Crime
# 0                     Character    122.0             Drama
# 0                     Character    122.0           Mystery
# 1      The Rise and Fall of ECW    360.0       Documentary
# 1      The Rise and Fall of ECW    360.0             Sport
# ...                         ...      ...               ...
# 10883              Alien Hunter     92.0  Millennium Films
# 10883              Alien Hunter     92.0            Action
# 10883              Alien Hunter     92.0         Adventure
# 10883              Alien Hunter     92.0             SciFi
# 10883              Alien Hunter     92.0          Thriller
#
# [50552 rows x 3 columns]

# %%
df_movies_crosstab = pd.crosstab(df_movies_encoded_filtered['title'], df_movies_encoded_filtered['tags'])
df_movies_crosstab.head()
# Out:
# tags                             20th Century Fox Television  \
# title
# 'N Sync: Unauthorized Biography                            0
# 'Round Midnight                                            0
# ... And God Spoke                                          0
# ...And Justice for All                                     0
# ...And Then Came Summer                                    0
#
# tags                             3 Arts Entertainment  \
# title
# 'N Sync: Unauthorized Biography                     0
# 'Round Midnight                                     0
# ... And God Spoke                                   0
# ...And Justice for All                              0
# ...And Then Came Summer                             0
#
# tags                             40 Acres & A Mule Filmworks  A Band Apart  \
# title
# 'N Sync: Unauthorized Biography                            0             0
# 'Round Midnight                                            0             0
# ... And God Spoke                                          0             0
# ...And Justice for All                                     0             0
# ...And Then Came Summer                                    0             0
#
# tags                             A&E Television Networks  A&M Films  \
# title
# 'N Sync: Unauthorized Biography                        0          0
# 'Round Midnight                                        0          0
# ... And God Spoke                                      0          0
# ...And Justice for All                                 0          0
# ...And Then Came Summer                                0          0
#
# tags                             Abel Ferrara  Action  Aditya Chopra  \
# title
# 'N Sync: Unauthorized Biography             0       0              0
# 'Round Midnight                             0       0              0
# ... And God Spoke                           0       0              0
# ...And Justice for All                      0       0              0
# ...And Then Came Summer                     0       0              0
#
# tags                             Adventure  ...  Working Title Films  \
# title                                       ...
# 'N Sync: Unauthorized Biography          0  ...                    0
# 'Round Midnight                          0  ...                    0
# ... And God Spoke                        0  ...                    0
# ...And Justice for All                   0  ...                    0
# ...And Then Came Summer                  0  ...                    0
#
# tags                             World International Network  Yash Chopra  \
# title
# 'N Sync: Unauthorized Biography                            0            0
# 'Round Midnight                                            0            0
# ... And God Spoke                                          0            0
# ...And Justice for All                                     0            0
# ...And Then Came Summer                                    0            0
#
# tags                             Yash Raj Films  Yasujirô Ozu  \
# title
# 'N Sync: Unauthorized Biography               0             0
# 'Round Midnight                               0             0
# ... And God Spoke                             0             0
# ...And Justice for All                        0             0
# ...And Then Came Summer                       0             0
#
# tags                             Zentropa Entertainments  Zoetrope Studios  \
# title
# 'N Sync: Unauthorized Biography                        0                 0
# 'Round Midnight                                        0                 0
# ... And God Spoke                                      0                 0
# ...And Justice for All                                 0                 0
# ...And Then Came Summer                                0                 0
#
# tags                             Zweites Deutsches Fernsehen  liang Tsai  \
# title
# 'N Sync: Unauthorized Biography                            0           0
# 'Round Midnight                                            0           0
# ... And God Spoke                                          0           0
# ...And Justice for All                                     0           0
# ...And Then Came Summer                                    0           0
#
# tags                             Éric Rohmer
# title
# 'N Sync: Unauthorized Biography            0
# 'Round Midnight                            0
# ... And God Spoke                          0
# ...And Justice for All                     0
# ...And Then Came Summer                    0
#
# [5 rows x 1000 columns]

# %%
df_movies_crosstab.sum(axis=1).sort_values()
# Out:
# title
# The Mouse That Roared            1
# The Best of Benny Hill           1
# The Best of Riverdance           1
# Diary of Jack the Ripper         1
# The Sex Monster                  1
#                               ...
# Hamlet                         104
# Peter Pan                      108
# Pinocchio                      108
# Anna Karenina                  125
# The Hunchback of Notre Dame    138
# Length: 9819, dtype: int64

# %% [markdown]
# There is no movie with 0 tag, so we may good to go.

# %%
# CALCULATE THE JACCARD SIMILARITY
from scipy.spatial.distance import pdist, squareform

# Calculate all pairwise distances
jaccard_distances = pdist(df_movies_crosstab.values, metric='jaccard')

# Convert the distances to a square matrix
jaccard_similarity_array = 1 - squareform(jaccard_distances)

# Wrap the array in a pandas DataFrame
jaccard_similarity_df = pd.DataFrame(jaccard_similarity_array, columns=df_movies_crosstab.index, index=df_movies_crosstab.index)

# Print the top 5 rows of the DataFrame
display(jaccard_similarity_df.head())
# Out:
# title                            'N Sync: Unauthorized Biography  \
# title
# 'N Sync: Unauthorized Biography                             1.00
# 'Round Midnight                                             0.25
# ... And God Spoke                                           0.00
# ...And Justice for All                                      0.00
# ...And Then Came Summer                                     0.00
#
# title                            'Round Midnight  ... And God Spoke  \
# title
# 'N Sync: Unauthorized Biography         0.250000                0.0
# 'Round Midnight                         1.000000                0.0
# ... And God Spoke                       0.000000                1.0
# ...And Justice for All                  0.125000                0.0
# ...And Then Came Summer                 0.333333                0.0
#
# title                            ...And Justice for All  \
# title
# 'N Sync: Unauthorized Biography                0.000000
# 'Round Midnight                                0.125000
# ... And God Spoke                              0.000000
# ...And Justice for All                         1.000000
# ...And Then Came Summer                        0.166667
#
# title                            ...And Then Came Summer  .Com for Murder  \
# title
# 'N Sync: Unauthorized Biography                 0.000000            0.000
# 'Round Midnight                                 0.333333            0.000
# ... And God Spoke                               0.000000            0.000
# ...And Justice for All                          0.166667            0.125
# ...And Then Came Summer                         1.000000            0.000
#
# title                                  10  10 Attitudes  \
# title
# 'N Sync: Unauthorized Biography  0.000000      0.000000
# 'Round Midnight                  0.125000      0.250000
# ... And God Spoke                0.166667      0.500000
# ...And Justice for All           0.090909      0.142857
# ...And Then Came Summer          0.166667      0.500000
#
# title                            10 Things I Hate About You  10 to Midnight  \
# title
# 'N Sync: Unauthorized Biography                    0.000000        0.000000
# 'Round Midnight                                    0.142857        0.142857
# ... And God Spoke                                  0.200000        0.000000
# ...And Justice for All                             0.100000        0.375000
# ...And Then Came Summer                            0.200000        0.200000
#
# title                            ...  Zigzag  \
# title                            ...
# 'N Sync: Unauthorized Biography  ...     0.0
# 'Round Midnight                  ...     0.0
# ... And God Spoke                ...     0.0
# ...And Justice for All           ...     0.0
# ...And Then Came Summer          ...     0.0
#
# title                            Zion Canyon: Treasure of the Gods: IMAX  \
# title
# 'N Sync: Unauthorized Biography                                 0.333333
# 'Round Midnight                                                 0.000000
# ... And God Spoke                                               0.000000
# ...And Justice for All                                          0.000000
# ...And Then Came Summer                                         0.000000
#
# title                            Zombie  Zombie 3  Zombie Holocaust  \
# title
# 'N Sync: Unauthorized Biography     0.0       0.0               0.0
# 'Round Midnight                     0.0       0.0               0.0
# ... And God Spoke                   0.0       0.0               0.0
# ...And Justice for All              0.0       0.0               0.0
# ...And Then Came Summer             0.0       0.0               0.0
#
# title                            Zoolander  Zoot Suit  Zorba the Greek  \
# title
# 'N Sync: Unauthorized Biography        0.0   0.000000         0.000000
# 'Round Midnight                        0.0   0.200000         0.200000
# ... And God Spoke                      0.2   0.000000         0.333333
# ...And Justice for All                 0.0   0.125000         0.125000
# ...And Then Came Summer                0.0   0.333333         0.333333
#
# title                            Zubeidaa      Zulu
# title
# 'N Sync: Unauthorized Biography  0.000000  0.000000
# 'Round Midnight                  0.142857  0.200000
# ... And God Spoke                0.000000  0.000000
# ...And Justice for All           0.100000  0.125000
# ...And Then Came Summer          0.200000  0.333333
#
# [5 rows x 9819 columns]

# %%
movie = "Zombie 3"

# Find the values for the movie
jaccard_similarity_series = jaccard_similarity_df.loc[movie]

# Sort these values from highest to lowest
ordered_similarities = jaccard_similarity_series.sort_values(ascending=False)

# Print the results
print("Top 20 movies similar to {}:".format(movie))
display(ordered_similarities.iloc[1:21].to_frame())
# Out:
# Top 20 movies similar to Zombie 3:
#                                              Zombie 3
# title
# Reign in Darkness                            1.000000
# Dead Meat                                    0.750000
# Godzilla vs. Megaguirus                      0.750000
# Death Machine                                0.750000
# Raptor                                       0.750000
# Starship Troopers 2: Hero of the Federation  0.750000
# Predator Island                              0.750000
# The Crazies                                  0.750000
# Reptilian                                    0.750000
# Avia Vampire Hunter                          0.666667
# The Final Countdown                          0.666667
# Phantasm                                     0.666667
# Invaders from Mars                           0.666667
# Teenagers from Outer Space                   0.666667
# Sabretooth                                   0.666667
# The Unearthly                                0.666667
# Embryo                                       0.666667
# The Bone Snatcher                            0.666667
# Carnivore                                    0.666667
# Stakes                                       0.666667
