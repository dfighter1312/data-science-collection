# %% [markdown]
# # Data Scientist Associate Practical Exam Submission
#
# Candidate: Hoang-Dung Nguyen (Nguyễn Hoàng Dũng)

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, make_scorer, f1_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Task 1
#
# For every column in the data:
#
# **a. State whether the values match the description given in the table.**

# %%
# Import the dataframe
df = pd.read_csv('electric_bike_ratings_2212.csv')
df.head()
# Out:
#    owned     make_model  ... value_for_money overall_rating
# 0      1   Nielah-Eyden  ...            5/10          18.62
# 1      0  Nielah-Keetra  ...            4/10          15.55
# 2      0   Lunna-Keetra  ...            5/10          12.76
# 3      1   Hoang-Keetra  ...            5/10          17.07
# 4      1   Lunna-Keetra  ...            5/10          12.29
#
# [5 rows x 8 columns]

# %%
# See the information of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   owned            1500 non-null   int64
#  1   make_model       1500 non-null   object
#  2   review_month     1500 non-null   object
#  3   web_browser      1350 non-null   object
#  4   reviewer_age     1500 non-null   object
#  5   primary_use      1500 non-null   object
#  6   value_for_money  1500 non-null   object
#  7   overall_rating   1500 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 93.9+ KB

# %%
# Observe distinct values in categorical columns
for col in df.select_dtypes(['int', 'object']):
    nunique = df[col].nunique()
    unique_vals = df[col].unique().tolist()
    print(f'{col :-<30} ({nunique}) {unique_vals}')
# Out:
# owned------------------------- (2) [1, 0]
# make_model-------------------- (6) ['Nielah-Eyden', 'Nielah-Keetra', 'Lunna-Keetra', 'Hoang-Keetra', 'Lunna-Eyden', 'Hoang-Eyden']
# review_month------------------ (332) ['Oct', 'Jun', '23-Oct', '07-Nov', '16-Sep', '26-Aug', '01-Mar', '15-Mar', '09-Mar', 'Jul', '10-Nov', 'Mar', 'Apr', 'Sep', '27-Dec', '11-Nov', '07-Dec', 'Feb', 'Jan', '06-Jun', '12-Jul', '02-Aug', '23-Feb', '27-Jul', '26-Nov', '30-Apr', '31-Jul', '22-Nov', '05-Sep', '05-Dec', '21-Jul', '15-Nov', '07-Jun', '20-May', '23-Sep', '10-Sep', '19-Oct', '28-Oct', '08-Apr', '14-Feb', '28-Nov', '28-Feb', '28-Jul', '12-Apr', '25-Apr', '25-Oct', '08-Jul', '29-Mar', '22-Sep', '26-Jun', '24-May', '12-Mar', '15-Feb', '28-Aug', 'May', '16-Jun', '02-Jul', '06-Feb', '21-Jun', 'Nov', '21-Apr', '19-Jul', '31-May', '11-Aug', '14-Mar', '12-Dec', '02-Apr', '23-Aug', '11-Feb', '24-Aug', '03-Jun', '01-Apr', '24-Nov', 'Dec', '26-Mar', '22-Oct', '22-Jan', '17-Mar', '05-Oct', '20-Mar', '13-Jul', '03-Oct', '16-Nov', '10-Apr', '12-Aug', '19-Aug', '09-Oct', 'Aug', '05-Nov', '23-Dec', '06-Jul', '03-Feb', '21-May', '03-Jul', '10-May', '12-Jun', '20-Oct', '17-Sep', '24-Feb', '24-Sep', '14-Sep', '07-Sep', '30-Nov', '17-Jun', '16-Dec', '16-Jul', '23-Jun', '16-Mar', '01-Jul', '29-Sep', '26-Dec', '06-Apr', '26-Jul', '01-Sep', '30-Mar', '19-Jan', '11-Dec', '15-Oct', '27-Jan', '27-Aug', '17-Jan', '04-Dec', '11-Jan', '22-Mar', '19-Sep', '03-Aug', '20-Jun', '07-May', '11-May', '29-Dec', '06-Dec', '30-Jun', '10-Oct', '27-Jun', '17-Apr', '29-Jul', '29-Aug', '17-Feb', '06-Oct', '22-Feb', '24-Dec', '21-Oct', '22-Jun', '09-Jun', '16-Aug', '27-Oct', '13-Nov', '25-Mar', '19-Nov', '31-Jan', '05-May', '08-Aug', '21-Sep', '04-May', '26-Jan', '22-Dec', '15-Dec', '03-Sep', '24-Oct', '21-Feb', '19-May', '07-Apr', '12-Jan', '29-Jun', '20-Apr', '14-Jul', '11-Jun', '03-May', '08-Oct', '14-Dec', '13-Jan', '29-May', '28-Dec', '02-May', '18-Sep', '16-Jan', '27-Apr', '05-Jun', '25-Dec', '19-Feb', '23-May', '06-Jan', '05-Mar', '30-Jan', '26-May', '20-Dec', '13-Oct', '17-Aug', '05-Jan', '08-Dec', '22-Aug', '30-Aug', '28-Jan', '06-Sep', '06-Nov', '26-Oct', '14-Nov', '01-May', '13-Sep', '26-Feb', '08-May', '09-Dec', '28-Mar', '28-May', '19-Jun', '25-May', '13-May', '30-Jul', '08-Nov', '15-Aug', '18-May', '15-Jun', '10-Feb', '20-Sep', '14-Apr', '07-Jan', '24-Jun', '18-Aug', '04-Apr', '11-Jul', '10-Jul', '29-Jan', '17-Dec', '15-Jan', '08-Mar', '15-Sep', '02-Feb', '14-May', '17-Nov', '28-Apr', '10-Dec', '19-Mar', '06-Mar', '11-Mar', '18-Feb', '17-May', '21-Aug', '18-Apr', '12-Oct', '03-Jan', '04-Jul', '21-Mar', '02-Jun', '10-Jun', '03-Apr', '27-Feb', '09-Aug', '04-Jun', '24-Jan', '14-Jan', '18-Dec', '09-Feb', '02-Mar', '02-Dec', '24-Apr', '25-Sep', '13-Jun', '14-Jun', '02-Nov', '21-Dec', '04-Sep', '01-Aug', '16-Apr', '23-Apr', '18-Mar', '11-Apr', '05-Aug', '27-Sep', '18-Jan', '22-Jul', '12-May', '05-Apr', '07-Feb', '28-Sep', '13-Aug', '05-Feb', '10-Mar', '16-Feb', '04-Feb', '31-Dec', '02-Oct', '30-May', '25-Nov', '25-Aug', '06-May', '08-Jun', '29-Apr', '01-Nov', '08-Sep', '18-Nov', '09-Apr', '02-Jan', '20-Nov', '21-Nov', '03-Dec', '20-Feb', '16-May', '18-Oct', '12-Nov', '30-Sep', '12-Sep', '20-Aug', '26-Apr', '07-Aug', '12-Feb', '04-Aug', '10-Aug', '24-Mar', '01-Jun', '01-Jan', '22-May', '09-Jan', '15-May', '18-Jun', '30-Oct', '26-Sep', '04-Mar', '15-Apr', '04-Oct', '11-Oct', '04-Nov', '08-Jan', '07-Jul', '21-Jan', '16-Oct', '14-Aug', '29-Nov', '23-Jan', '23-Jul', '23-Nov', '09-May', '06-Aug']
# web_browser------------------- (6) ['Chrome', nan, 'IE', 'Firefox', 'Safari', 'Android', 'Opera']
# reviewer_age------------------ (36) ['23', '24', '28', '41', '33', '47', '20', '32', '35', '22', '29', '39', '42', '36', '40', '27', '48', '34', '16', '21', '25', '30', '-', '46', '37', '31', '17', '44', '26', '38', '49', '50', '45', '19', '43', '18']
# primary_use------------------- (2) ['Commuting', 'Leisure']
# value_for_money--------------- (10) ['5/10', '4/10', '3/10', '7/10', '6/10', '2/10', '9/10', '8/10', '10/10', '1/10']

# %%
df['overall_rating'].describe()
# Out:
# count    1500.000000
# mean       17.138907
# std         2.445566
# min        11.690000
# 25%        15.320000
# 50%        18.240000
# 75%        18.840000
# max        22.760000
# Name: overall_rating, dtype: float64

# %% [markdown]
# **My observation:**
#
# - `owned` matches the description since there are only 0 and 1 as distinct values.
# - `make_model` matches the description with the 6 possible values as mentioned.
# - `review_month` does not match the description. There is record with month only while record with format `date-month` exists in the data.
# - `web_browser` matches the description, there is also `nan` indicating the missing value.
# - `reviewer_age` contains value `-`, which may indicate a missing value, but making the parser thinks that this is a object column (integer expected).
# - `primary_use` matches the description.
# - `value_for_money` should be integers instead of the format `score/10`
# - `overall_rating` matches the description, with the values in range [11.69, 22.76] (description accepts from 0 to 25).

# %% [markdown]
# **b. State the number of missing values in the column**

# %%
df.isna().sum()
# Out:
# owned                0
# make_model           0
# review_month         0
# web_browser        150
# reviewer_age         0
# primary_use          0
# value_for_money      0
# overall_rating       0
# dtype: int64

# %% [markdown]
# There are 150 missing values in `web_browser` column and 105 in `reviewer_age` (if `-` is considered as the missing value). The remaining columns contain all non-null values.

# %% [markdown]
# **c. Describe what you did to make values match the description if they did not match.**
#
# - `review_month`: for these values with format `date-month`, I will split the date and month using the `.split(-)` function, then only take the month as the final value.
# - `web_browser`: replace `nan` with `unknown`
# - `reviewer_age` replace `-` with `nan`, convert it into numeric column, then fill the missing values with the average age as required.
# - `value_for_money`: take `score` from the format `score/10` using `.split(/)`.

# %%
# Fix on the columns that does not match the description
df['owned'] = df['owned'].astype('category')
df['make_model'] = df['make_model'].astype('category')
df['review_month'] = df['review_month'].map(lambda x: x if len(x.split('-')) == 1 else x.split('-')[1])
df['review_month'] = df['review_month'].astype('category')
df['web_browser'] = df['web_browser'].replace('-', 'unknown')
df['web_browser'] = df['web_browser'].astype('category')
df['reviewer_age'] = df['reviewer_age'].replace('-', np.nan)
df['reviewer_age'] = df['reviewer_age'].astype('Int16')
df['reviewer_age'] = df['reviewer_age'].fillna(round(df['reviewer_age'].mean()))
df['primary_use'] = df['primary_use'].astype('category')
df['value_for_money'] = df['value_for_money'].map(lambda x: x.split('/')[0])
df['value_for_money'] = df['value_for_money'].astype('Int16')

# %% [markdown]
# ## Task 2
#
# Create a visualization that shows how many reviews were from owners and how many were not owners. Use the visualization to:
#
# **a. State which category of the variable owned has the most number of observations**
#
# Category `1` (owned) has the most number of observations.
#
# **b. Explain whether the observations are balanced across categories of the variable owned**
#
# The observations between categories are imbalanced since the heights

# %%
plt.figure()
owned_value_counts = df['owned'].value_counts()
owned_value_counts.plot.bar()
plt.title("Number of observations across categories of the variable owned")
plt.xlabel("Category")
plt.ylabel("Observations")
plt.show()

# %% [markdown]
# ## Task 3
#
# Describe the distribution of the overall rating across the possible values. Your answer must include a visualization that shows the distribution.

# %% [markdown]
# The overall rating follows a trimodal distribution, which has three distinct peaks. This means that the data is divided into three groups that have higher frequencies than the rest of the data.

# %% [markdown]
# ## Task 4
#
# Describe the relationship between ownership and overall rating. Your answer must include a visualization to demonstrate the relationship.

# %%
plt.figure()
sns.boxplot(data=df, x="overall_rating", y="owned")
plt.title("Distribution of overall rating across ownership")
plt.show()

# %% [markdown]
# The overall rating of reviews of the owner are likely to get higher than of the one who does not own the mopes.

# %% [markdown]
# ## Task 5
#
# The business wants to predict whether a review came from an owner or not using the data provided. State the type of machine learning problem that this is (regression/classification/clustering).
#
# _My answer:_
# This is a **classification problem**, where we want to map the provided features to predict the likelihood that the review came from an owner or not.

# %% [markdown]
# ## Task 6
#
# Fit a baseline model to predict whether a review came from an owner or not using the data provided. You must include your code.
#
# _My answer:_
#
# I'd be using Logistic Regression as the baseline model. About processing the data, I will keep the discrete and continuous columns, and perform One Hot Encoding (via `pd.get_dummies()`) for other categorical columns.

# %%
# Double check my dataframe (processed)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   owned            1500 non-null   category
#  1   make_model       1500 non-null   category
#  2   review_month     1500 non-null   category
#  3   web_browser      1350 non-null   category
#  4   reviewer_age     1500 non-null   Int16
#  5   primary_use      1500 non-null   category
#  6   value_for_money  1500 non-null   Int16
#  7   overall_rating   1500 non-null   float64
# dtypes: Int16(2), category(5), float64(1)
# memory usage: 29.0 KB

# %%
# Process the data and perform train-test split
y = df.pop('owned').values.reshape(-1, 1)
X = pd.get_dummies(df).values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("X_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("X_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (1050, 29)
# y_train shape:  (1050, 1)
# X_test shape:  (450, 29)
# y_test shape:  (450, 1)

# %%
baseline = LogisticRegression(random_state=42)
baseline.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# ## Task 7
#
# I will use Random Forest as the comparison model. I will also perform hyperparameter tuning for this task.

# %%
# Choose the type of classifier 
rf_estimator_tuned = RandomForestClassifier(criterion="entropy", random_state=42)

# Define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 7],
    'min_samples_leaf': [1, 5, 20],
    'max_features': [0.8, 0.9]
}

# Type of scoring used to compare parameter combinations - recall score for class 1
scorer = make_scorer(f1_score, pos_label = 1)

# Run the grid search on the training data using scorer=scorer and cv=3
grid_obj = GridSearchCV(rf_estimator_tuned, param_grid, scoring = scorer, cv=3, verbose=3)
grid_obj = grid_obj.fit(X_train, y_train)

# Save the best estimator to variable comparison
comparison = grid_obj.best_estimator_

#Fit the best estimator to the training data
comparison.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=50;, score=0.777 total time=   0.1s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=50;, score=0.792 total time=   0.1s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=50;, score=0.770 total time=   0.1s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=100;, score=0.776 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=100;, score=0.790 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=100;, score=0.767 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=150;, score=0.771 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=150;, score=0.796 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=1, n_estimators=150;, score=0.773 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=50;, score=0.772 total time=   0.1s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=50;, score=0.791 total time=   0.1s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=50;, score=0.768 total time=   0.1s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=100;, score=0.772 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=100;, score=0.780 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=100;, score=0.764 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=150;, score=0.771 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=150;, score=0.794 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=5, n_estimators=150;, score=0.767 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=50;, score=0.767 total time=   0.1s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=50;, score=0.798 total time=   0.1s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=50;, score=0.783 total time=   0.1s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=100;, score=0.769 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=100;, score=0.794 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=100;, score=0.772 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=150;, score=0.765 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=150;, score=0.801 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.8, min_samples_leaf=20, n_estimators=150;, score=0.775 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=50;, score=0.790 total time=   0.1s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=50;, score=0.772 total time=   0.1s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=100;, score=0.780 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=100;, score=0.790 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=100;, score=0.774 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=150;, score=0.785 total time=   0.3s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=150;, score=0.795 total time=   0.3s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=1, n_estimators=150;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=50;, score=0.774 total time=   0.1s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=50;, score=0.796 total time=   0.1s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=50;, score=0.776 total time=   0.1s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=100;, score=0.783 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=100;, score=0.785 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=100;, score=0.770 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=150;, score=0.765 total time=   0.3s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=150;, score=0.789 total time=   0.3s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=5, n_estimators=150;, score=0.770 total time=   0.3s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=50;, score=0.805 total time=   0.1s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=100;, score=0.770 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=100;, score=0.795 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=100;, score=0.779 total time=   0.2s
# [CV 1/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=150;, score=0.771 total time=   0.2s
# [CV 2/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=150;, score=0.799 total time=   0.2s
# [CV 3/3] END max_depth=5, max_features=0.9, min_samples_leaf=20, n_estimators=150;, score=0.780 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=50;, score=0.772 total time=   0.1s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=100;, score=0.772 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=100;, score=0.765 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=100;, score=0.770 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=150;, score=0.774 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=150;, score=0.770 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=1, n_estimators=150;, score=0.770 total time=   0.3s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=50;, score=0.772 total time=   0.1s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=50;, score=0.787 total time=   0.1s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=50;, score=0.774 total time=   0.1s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=100;, score=0.770 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=100;, score=0.790 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=100;, score=0.766 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=150;, score=0.769 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=150;, score=0.793 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=5, n_estimators=150;, score=0.763 total time=   0.3s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=50;, score=0.770 total time=   0.1s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=50;, score=0.808 total time=   0.1s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=50;, score=0.787 total time=   0.1s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=100;, score=0.766 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=100;, score=0.794 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=100;, score=0.778 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=150;, score=0.764 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=150;, score=0.798 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.8, min_samples_leaf=20, n_estimators=150;, score=0.775 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=50;, score=0.777 total time=   0.1s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=50;, score=0.761 total time=   0.1s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=50;, score=0.768 total time=   0.1s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=100;, score=0.776 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=100;, score=0.763 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=100;, score=0.773 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=150;, score=0.775 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=150;, score=0.769 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=1, n_estimators=150;, score=0.781 total time=   0.3s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=50;, score=0.780 total time=   0.1s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=100;, score=0.781 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=100;, score=0.792 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=100;, score=0.770 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=150;, score=0.777 total time=   0.3s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=150;, score=0.793 total time=   0.3s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=5, n_estimators=150;, score=0.768 total time=   0.3s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=50;, score=0.769 total time=   0.1s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=50;, score=0.797 total time=   0.1s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=50;, score=0.782 total time=   0.1s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=100;, score=0.772 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=100;, score=0.793 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=100;, score=0.777 total time=   0.2s
# [CV 1/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=150;, score=0.767 total time=   0.2s
# [CV 2/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=150;, score=0.794 total time=   0.2s
# [CV 3/3] END max_depth=7, max_features=0.9, min_samples_leaf=20, n_estimators=150;, score=0.783 total time=   0.2s
# RandomForestClassifier(criterion='entropy', max_depth=7, max_features=0.8,
#                        min_samples_leaf=20, n_estimators=50, random_state=42)

# %% [markdown]
# ## Task 8
#
# Explain why you chose the two models used in parts 6 and 7.
#
# _My answer:_
#
# - The baseline model, Logistic Regression, is the most basic Machine Learning model for its simplicity. In addition, the training time that Logistic Regression takes is small so it is fast to obtain a baseline model.
# - On the other hand, Random Forest is an ensemble algorithm that consists of multiple shallow decision tree, which performs well in most cases for prediction problem.

# %% [markdown]
# ## Task 9
#
# Compare the performance of the two models used in parts 6 and 7, using any method suitable for the type of model. You must include your code.

# %%
def transform_and_scoring(X, y, model):
    """
    Transform the data to output labels using the fitted model. The function
    will output the scoring report.
    
    Args:
        X (np.ndarray or pd.DataFrame): Input data
        y (np.ndarray or pd.DataFrame): Expected output
        model (Any): Fitted model
    """
    
    y_pred = model.predict(X)
    print("Classification Report")
    print(classification_report(y, y_pred, digits=4))
    print("-" * 50)
    print("ROC AUC score: ", roc_auc_score(y, y_pred))
    print("-" * 50)
    print("Confusion matrix: ")
    plt.figure()
    sns.heatmap(confusion_matrix(y, y_pred), annot=True, fmt='g')
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.show()

# %%
# Evaluation of baseline model (Logistic Regression)
transform_and_scoring(X_train, y_train, baseline)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.7292    0.6452    0.6846       434
#            1     0.7688    0.8312    0.7988       616
#
#     accuracy                         0.7543      1050
#    macro avg     0.7490    0.7382    0.7417      1050
# weighted avg     0.7524    0.7543    0.7516      1050
#
# --------------------------------------------------
# ROC AUC score:  0.738165060745706
# --------------------------------------------------
# Confusion matrix:

# %%
transform_and_scoring(X_test, y_test, baseline)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.6918    0.6250    0.6567       176
#            1     0.7732    0.8212    0.7965       274
#
#     accuracy                         0.7444       450
#    macro avg     0.7325    0.7231    0.7266       450
# weighted avg     0.7414    0.7444    0.7418       450
#
# --------------------------------------------------
# ROC AUC score:  0.7230839416058394
# --------------------------------------------------
# Confusion matrix:

# %%
# Evaluation of comparison model (Random Forest)
transform_and_scoring(X_train, y_train, comparison)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.7820    0.6613    0.7166       434
#            1     0.7848    0.8701    0.8253       616
#
#     accuracy                         0.7838      1050
#    macro avg     0.7834    0.7657    0.7709      1050
# weighted avg     0.7836    0.7838    0.7803      1050
#
# --------------------------------------------------
# ROC AUC score:  0.7657100963552577
# --------------------------------------------------
# Confusion matrix:

# %%
transform_and_scoring(X_test, y_test, comparison)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.7292    0.5966    0.6562       176
#            1     0.7680    0.8577    0.8103       274
#
#     accuracy                         0.7556       450
#    macro avg     0.7486    0.7271    0.7333       450
# weighted avg     0.7528    0.7556    0.7501       450
#
# --------------------------------------------------
# ROC AUC score:  0.7271275713337757
# --------------------------------------------------
# Confusion matrix:

# %% [markdown]
# ## Task 10
#
# Explain which model performs better and why.
#
# _My answer:_
#
# I have used 3 metrics for comparison: accuracy, F1-score and ROC AUC score. Comparing between baseline and comparison model:
#
# - Accuracy:
#     - The baseline model gets 75.43% in training set, 74.44% in test set.
#     - The comparison model gets 78.38% in training set, 75.56% in test set.
#     - **Comparison model gets higher score in this metric.**
#
# - F1-score:
#     - The baseline model gets 74.17% in training set, 72.66% in test set.
#     - The comparison model gets 77.09% in training set, 73.33% in test set.
#     - **Comparison model gets higher score in this metric.**
#
# - ROC AUC score:
#     - The baseline model gets 0.7381 in training set, 0.7230 in test set.
#     - The comparison model gets 0.6758 in training set, 0.7271 in test set.
#     - **Comparison model gets higher score in this metric.**
#
# In general, the comparison model (Random Forest) performs better which gets higher evaluation in all the metrics.

# %% [markdown]
# ## ✅  When you have finished...
# - Publish your Workspace using the option on the left
# - Check the published version of your report:
# 	- Can you see everything you want us to grade?
#     - Are all the graphics visible?
# - Review the grading rubric. Have you included everything that will be graded?
# - Head back to the [Certification dashboard](https://app.datacamp.com/certification) to submit your practical exam
